# %%
import numpy

# %%
def sigmoid(x):
    return 1/(1+numpy.exp(-x))

# %%
def NN(m1,m2,w1,w2,b):
    z=m1*w1+m2*w2+b
    return sigmoid(z)

# %%
w1=numpy.random.randn()
w2=numpy.random.randn()
b=numpy.random.randn()

# %%
def cost(pred):
    return (pred-4)**2

# %%
def costSlope(costNr):
    return 2*(b-4)

# %%
costSlope(5)
# Out:
# -9.863487798377005

# %%
b=-20
for i in range (100):
    b=b-.1*costSlope(b)
    print(b)
# Out:
# -15.2
# -11.36
# -8.288
# -5.8304
# -3.8643199999999998
# -2.2914559999999997
# -1.0331647999999996
# -0.02653183999999964
# 0.7787745280000004
# 1.4230196224000005
# 1.9384156979200005
# 2.3507325583360004
# 2.6805860466688003
# 2.94446883733504
# 3.155575069868032
# 3.3244600558944257
# 3.4595680447155406
# 3.5676544357724325
# 3.654123548617946
# 3.723298838894357
# 3.7786390711154856
# 3.8229112568923886
# 3.858329005513911
# 3.886663204411129
# 3.9093305635289033
# 3.9274644508231225
# 3.941971560658498
# 3.9535772485267984
# 3.9628617988214385
# 3.970289439057151
# 3.9762315512457205
# 3.9809852409965765
# 3.9847881927972613
# 3.987830554237809
# 3.9902644433902474
# 3.992211554712198
# 3.9937692437697585
# 3.9950153950158067
# 3.9960123160126453
# 3.996809852810116
# 3.997447882248093
# 3.997958305798474
# 3.9983666446387796
# 3.998693315711024
# 3.998954652568819
# 3.999163722055055
# 3.999330977644044
# 3.9994647821152354
# 3.9995718256921884
# 3.9996574605537507
# ...
